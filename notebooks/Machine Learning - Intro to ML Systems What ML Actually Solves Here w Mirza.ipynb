# %% [markdown]
# **Problem Statement**

# %%
#The goal is to identify website content that is likely to decline in search performance so that content editors can refresh it before traffic drops significantly.

# %% [markdown]
# **Can Rules Solve This?**

# %%
#"A rule such as "CTR < 2%" is unreliable because search performance depends on multiple interacting factors including impressions, average position, sessions, and content age. Machine learning can learn these relationships better than fixed thresholds."

# %% [markdown]
# **3. AI vs ML vs Rules**

# %%
#| Concept          | Description                  |
#| ---------------- | ---------------------------- |
#| Rules            | Human-written logic          |
#| Analytics        | Describes what happened      |
#| Machine Learning | Learns patterns from data    |
#| AI               | Broad field that includes ML |

# %% [markdown]
# **ML Loop**

# %%
#Business Problem
#↓

#Collect Data
#↓

#Prepare Data
#↓

#Train Model
#↓

#Evaluate
#↓

#Deploy
#↓

#Monitor

# %% [markdown]
# **5. Learning Type**

# %%
#Supervised Learning

#The dataset contains labels (is_declining_label), allowing the model to learn from examples.

# %% [markdown]
# **6. ML Task Type**

# %%
#Classification

#The model predicts whether a page is declining or not

# %% [markdown]
# **Target Variable**

# %%
#is_declining_label
#1	0.542067
#0	0.457933

# %% [markdown]
# **9. Success Metrics**

# %%
#Precision 20
#ROC-AUC 14
#Average Precision 15

# %% [markdown]
# **Why Machine Learning?**

# %%
#Machine learning is appropriate because content performance depends on many variables whose relationships are difficult to capture using fixed rules. A supervised classification model can learn these patterns and prioritize pages more effectively.
